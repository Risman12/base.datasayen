# %%
import matplotlib.pyplot as plt

# %%
print("=== soal 1 ===")
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLY','KESENIAN','ROHIS']
pengikut = [5, 18, 30, 7, 16, 19, 12]
c = ['red', 'blue', 'green']
plt.title("SISWA KALAS 10 YANG MENGIKUTI ESKUL ")
plt.bar(eskul, pengikut, color = c)
plt.show()
print()
# Out:
# === soal 1 ===

# %%
print("=== soal 2 ===")
p10 = 5
p11 = 21
p12 = 6
juml = p10 + p11 + p12
print("jumlah yang mengikuti paskibra : " + str(juml))

p10 = 18
p11 = 4
p12 = 12
juml = p10 + p11 + p12
print("jumlah yang mengikuti pmr : " + str(juml))

p10 = 30
p11 = 8
p12 = 24
juml = p10 + p11 + p12
print("jumlah yang mengikuti pramuka : " + str(juml))

p10 = 7
p11 = 29
p12 = 15
juml = p10 + p11 + p12
print("jumlah yang mengikuti futsal : " + str(juml))

p10 = 16
p11 = 10
p12 = 12
juml = p10 + p11 + p12
print("jumlah yang mengikuti volly : " + str(juml))

p10 = 19
p11 = 18
p12 = 4
juml = p10 + p11 + p12
print("jumlah yang mengikuti kesenian : " + str(juml))

p10 = 12
p11 = 10
p12 = 7
juml = p10 + p11 + p12
print("jumlah yang mengikuti rohis : " + str(juml))

print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['PASKIBRA','PMR','PRAMUKA','FUTSAL','VOLY','KESENIAN','ROHIS']
pengikut = [32, 34, 62, 51, 38, 41, 29]
c = ['red', 'blue', 'green']
plt.title("SISWA YANG MENGIKUTI ESKUL ")
plt.bar(eskul, pengikut, color = c)
plt.show()
print()
# Out:
# === soal 2 ===
# jumlah yang mengikuti paskibra : 32
# jumlah yang mengikuti pmr : 34
# jumlah yang mengikuti pramuka : 62
# jumlah yang mengikuti futsal : 51
# jumlah yang mengikuti volly : 38
# jumlah yang mengikuti kesenian : 41
# jumlah yang mengikuti rohis : 29

# %%
print("=== soal 3 ===")
fut10 =7
fut11 =29
fut12 =15
volly10 =16
volly11 =10
volly12 =12
juml1 = fut10 + fut11 + fut12 + volly10 + volly11 + volly12
print("jumlah yang mengikuti olah raga : "+ str(juml1))


a = 107
b = 8
c = 20
juml2 = (a + b + c)
print("jumlah yang mengikuti eskul adalah  : "+ str(juml2))
juml = (juml1-juml2)
print("jumlah yang mengikuti olah raga : "+ str(juml))

a = 17
b = 8
c = 20
juml3 = (a + b + c)
print("jumlah siswa yang tidak mengikuti eskul adalah : " +str(juml3))

a = 89
b = 198
c = 45
juml = (a + b + c)
print("jumlah siswa yang tidak mengikuti eskul adalah : " +str(juml))

juml1 =(a * 100 / juml )
juml2 =(b * 100 / juml )
juml3 =(c * 100 / juml )
print("persentase dari kelas 10 adalah :" +str(juml1))
print("persentase dari kelas 11 adalah :" +str(juml2))
print("persentase dari kelas 12 adalah :" +str(juml3))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ['OLAHRAGA','MENGIKUTI','TIDAK MENGIKUTI']
siswa = [89, 198, 45]
c = ['red', 'blue', 'green']
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL DI KELAS 10")
plt.bar(jurusan, siswa, color = c)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['OLAHRAGA','MENGIKUTI','TIDAK MENGIKUTI']
siswa = [89, 198, 45]
ax.pie(siswa,labels=jurusan,autopct= '%1.2f%%')
plt.title("JUMLAH SISWA YANG MENGGIKUTI ESKUL DI KELAS 10 ")
plt.show()

print( )
# Out:
# === soal 3 ===
# jumlah yang mengikuti olah raga : 89
# jumlah yang mengikuti eskul adalah  : 135
# jumlah yang mengikuti olah raga : -46
# jumlah siswa yang tidak mengikuti eskul adalah : 45
# jumlah siswa yang tidak mengikuti eskul adalah : 332
# persentase dari kelas 10 adalah :26.80722891566265
# persentase dari kelas 11 adalah :59.63855421686747
# persentase dari kelas 12 adalah :13.55421686746988

# %%
print("=== soal 4 ===")
p =17
p1 = 6
p2 =20
hasil = (p +p1+p2)
print("jumlah yang tidak mengikuti adalah :" +str(hasil))

a = 17
b = 8
c = 20
d = 45
hasil1 = (a * 100 / d )
hasil2 = (b * 100 / d )
hasil3 = (c * 100 / d )
print("persentasi dari kelas 10 adalah :" +str(hasil1))
print("jumlah yang tidak mengikuti adalah :" +str(hasil2))
print("jumlah yang tidak mengikuti adalah :" +str(hasil3))
hasil = (hasil1+hasil2+hasil3)
print ("total presentase : "+ str(hasil))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['KLS_10','KLS_11','KLS12']
siswa = [17, 8, 20]
ax.pie(siswa,labels=jurusan,autopct= '%1.2f%%')
plt.title("JUMLAH SISWA YANG MENGGIKUTI ESKUL DI KELAS 10 ")
plt.show()

print()
# Out:
# === soal 4 ===
# jumlah yang tidak mengikuti adalah :43
# persentasi dari kelas 10 adalah :37.77777777777778
# jumlah yang tidak mengikuti adalah :17.77777777777778
# jumlah yang tidak mengikuti adalah :44.44444444444444
# total presentase : 100.0

# %%
print("=== soal 5 ===")
print()
print(" == kelas 10 ==")
print()
k10_a = 5
k10_b = 18
k10_c = 30
k10_d = 7
k10_e = 16
k10_f = 19
k10_g = 12

k10 = (k10_a+k10_b+k10_c+k10_d+k10_e+k10_f+k10_g)
print("jumlah siswa yang mengikuti eskul di leas 10 adalah : "+ str(k10))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ['paskibra','pmr','pramuka','futsal','volly','kesenian','rohis']
siswa = [5, 18, 30, 7, 16, 19, 12]
c = ['red', 'blue', 'green']
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL DI KELAS 10")
plt.bar(jurusan, siswa, color = c)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['paskibra','pmr','pramuka','futsal','volly','kesenian','rohis']
siswa = [5, 18, 30, 7, 16, 19, 12]
ax.pie(siswa,labels=jurusan,autopct= '%1.2f%%')
plt.title("JUMLAH SISWA YANG MENGGIKUTI ESKUL DI KELAS 10 ")
plt.show()

print()
print(" == kelas 11==")
print()

k11_a = 21
k11_b = 4
k11_c = 8
k11_d = 29
k11_e = 10
k11_f = 18
k11_g = 10

k11 = (k11_a+k11_b+k11_c+k11_d+k11_e+k11_f+k11_g)
print("jumlah siswa yang mengikuti eskul di leas 10 adalah : "+ str(k11))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ['paskibra','pmr','pramuka','futsal','volly','kesenian','rohis']
siswa = [21, 4, 8, 29, 10, 18, 10]
c = ['red', 'blue', 'green']
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL DI KELAS 11")
plt.bar(jurusan, siswa, color = c)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['paskibra','pmr','pramuka','futsal','volly','kesenian','rohis']
siswa = [21, 4, 8, 29, 10, 18, 10]
ax.pie(siswa,labels=jurusan,autopct= '%1.2f%%')
plt.title("JUMLAH SISWA YANG MENGGIKUTI ESKUL DI KELAS 11 ")
plt.show()

print()
print(" == kelas 12==")
print()

k12_a = 6
k12_b = 12
k12_c = 24
k12_d = 15
k12_e = 12
k12_f = 4
k12_g = 7

k12 = (k12_a+k12_b+k12_c+k10_d+k12_e+k12_f+k12_g)
print("jumlah siswa yang mengikuti eskul di leas 12 adalah : "+ str(k12))
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ['paskibra','pmr','pramuka','futsal','volly','kesenian','rohis']
siswa = [6, 12, 24, 15, 12, 4, 7]
c = ['red', 'blue', 'green']
plt.title("JUMLAH SISWA YANG MENGIKUTI ESKUL DI KELAS 12")
plt.bar(jurusan, siswa, color = c)
plt.show()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['paskibra','pmr','pramuka','futsal','volly','kesenian','rohis']
siswa = [6, 12, 24, 15, 12, 4, 7]
ax.pie(siswa,labels=jurusan,autopct= '%1.2f%%')
plt.title("JUMLAH SISWA YANG MENGGIKUTI ESKUL DI KELAS 12 ")
plt.show()
# Out:
# === soal 5 ===
#
#  == kelas 10 ==
#
# jumlah siswa yang mengikuti eskul di leas 10 adalah : 107
#  == kelas 11==
#
# jumlah siswa yang mengikuti eskul di leas 10 adalah : 100
#  == kelas 1==
#
# jumlah siswa yang mengikuti eskul di leas 10 adalah : 72
